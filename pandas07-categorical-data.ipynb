# %%
import pandas as pd

# %%
import numpy as np

# %%
dados = {
    'nome':['joao', 'maria', 'josé', np.nan, 'pedro', 'joana', 'helder'],
    'sexo': ['m', 'f', 'm', np.nan, 'm', 'f', 'm'],
    'idade': [14, 15, np.nan, np.nan, 15, 14, np.nan],
    'nota': [4, 10, 7, np.nan, np.nan, 9, 10]
}
df = pd.DataFrame(dados)

# %%
df
# Out:
#    idade    nome  nota sexo
# 0   14.0    joao   4.0    m
# 1   15.0   maria  10.0    f
# 2    NaN    josé   7.0    m
# 3    NaN     NaN   NaN  NaN
# 4   15.0   pedro   NaN    m
# 5   14.0   joana   9.0    f
# 6    NaN  helder  10.0    m

# %%
df.dropna()
# Out:
#    idade   nome  nota sexo
# 0   14.0   joao   4.0    m
# 1   15.0  maria  10.0    f
# 5   14.0  joana   9.0    f

# %%
df.dropna(how='all')
# Out:
#    idade    nome  nota sexo
# 0   14.0    joao   4.0    m
# 1   15.0   maria  10.0    f
# 2    NaN    josé   7.0    m
# 4   15.0   pedro   NaN    m
# 5   14.0   joana   9.0    f
# 6    NaN  helder  10.0    m

# %%
df['serie'] = np.nan

# %%
df
# Out:
#    idade    nome  nota sexo  serie
# 0   14.0    joao   4.0    m    NaN
# 1   15.0   maria  10.0    f    NaN
# 2    NaN    josé   7.0    m    NaN
# 3    NaN     NaN   NaN  NaN    NaN
# 4   15.0   pedro   NaN    m    NaN
# 5   14.0   joana   9.0    f    NaN
# 6    NaN  helder  10.0    m    NaN

# %%
df.dropna(how='all', axis=1)
# Out:
#    idade    nome  nota sexo
# 0   14.0    joao   4.0    m
# 1   15.0   maria  10.0    f
# 2    NaN    josé   7.0    m
# 3    NaN     NaN   NaN  NaN
# 4   15.0   pedro   NaN    m
# 5   14.0   joana   9.0    f
# 6    NaN  helder  10.0    m

# %%
df.dropna(thresh=3)
# Out:
#    idade    nome  nota sexo  serie
# 0   14.0    joao   4.0    m    NaN
# 1   15.0   maria  10.0    f    NaN
# 2    NaN    josé   7.0    m    NaN
# 4   15.0   pedro   NaN    m    NaN
# 5   14.0   joana   9.0    f    NaN
# 6    NaN  helder  10.0    m    NaN

# %%
df['serie'].fillna(8, inplace=True)

# %%
df
# Out:
#    idade    nome  nota sexo  serie
# 0   14.0    joao   4.0    m    8.0
# 1   15.0   maria  10.0    f    8.0
# 2    NaN    josé   7.0    m    8.0
# 3    NaN     NaN   NaN  NaN    8.0
# 4   15.0   pedro   NaN    m    8.0
# 5   14.0   joana   9.0    f    8.0
# 6    NaN  helder  10.0    m    8.0

# %%
df['idade'].fillna(df['idade'].mean(), inplace=True)

# %%
df
# Out:
#    idade    nome  nota sexo  serie
# 0   14.0    joao   4.0    m    8.0
# 1   15.0   maria  10.0    f    8.0
# 2   14.5    josé   7.0    m    8.0
# 3   14.5     NaN   NaN  NaN    8.0
# 4   15.0   pedro   NaN    m    8.0
# 5   14.0   joana   9.0    f    8.0
# 6   14.5  helder  10.0    m    8.0
